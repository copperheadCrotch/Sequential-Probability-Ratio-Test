# %%
# SPRT 
# Binomial Endpoints
import sprt as sprt
import numpy as np

# Null value
h0 = 0.5
# Alternative value
h1 = 0.55
# Type I error rate = 0.05
alpha = 0.05
# Type II error rate = 0.2
beta = 0.2
# Values
values = np.random.binomial(1, 0.55, 100)
test = sprt.SPRTBinomial(h0 = h0, h1 = h1, alpha = alpha, beta = beta, values = values)
# Out:
# Decision:	Continue
#
#      values   lower   upper
# n
# 91       46  40.014  61.595
# 92       46  40.539  62.120
# 93       46  41.064  62.646
# 94       47  41.589  63.171
# 95       47  42.114  63.696
# 96       48  42.639  64.221
# 97       49  43.164  64.746
# 98       50  43.689  65.271
# 99       50  44.214  65.796
# 100      51  44.740  66.321

# %%
test.plot()

# %%
# Plot the boundary only
test.plotBoundary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f199e21f2e47> in <module>()
# ----> 1 test.plotBoundary()
#
# F:\Python34\lib\site-packages\sprt-0.0.1-py3.4.egg\sprt\sprt.py in plotBoundary(self, boundaryColor, fill)
#      91         if fill:
#      92
# ---> 93             ax.fill_between(self.x, self._yl, ymin, color = lowerBoundaryColor, alpha = 0.5)
#      94             # ax.fill_between(self._seq_observation, self.lowerBoundary, self.upperBoundary, color = continueColor, alpha = 0.5)
#      95             ax.fill_between(self._x, self._yu, ymax, color = upperBoundaryColor, alpha = 0.5)
#
# AttributeError: 'SPRTBinomial' object has no attribute 'x'

# %%
# Plot the data and boundary but without fill the color
test.plot(fill = False)
